# %% [markdown]
# # IPL 2008-2020 DATA PREPROCESSING AND EDA

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Introduction
#
# Indian Premier League is the biggest cricket T-20 league in world that takes place in INDIA.
# Here I have all the matches details from 2008-2020.
# I will be analyzing the factors and patterns that helps teams to win matches by using libraries of Python such as Numpy and Pandas for data manipulation and for visualization I have used Matplotlib,Seaborn.

# %%
# importing required libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Transforming Data into Dataframe

df=pd.read_csv('IPL Matches 2008-2020.csv')

# %%
# Checking The Data

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %% [markdown]
# # Data preprocessing
#
# Imputing Null-Values

# %%
df.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
# Found missing values in city,player_of_match,winner,result,result_margin,method

# %%
df[df["city"].isnull()]
# Out:
#          id city        date player_of_match  \
# 399  729281  NaN  2014-04-17       YS Chahal
# 402  729287  NaN  2014-04-19        PA Patel
# 403  729289  NaN  2014-04-19       JP Duminy
# 404  729291  NaN  2014-04-20      GJ Maxwell
# 406  729295  NaN  2014-04-22      GJ Maxwell
# 407  729297  NaN  2014-04-23       RA Jadeja
# 408  729299  NaN  2014-04-24         CA Lynn
# 409  729301  NaN  2014-04-25        AJ Finch
# 410  729303  NaN  2014-04-25       MM Sharma
# 413  729309  NaN  2014-04-27         M Vijay
# 414  729311  NaN  2014-04-27        DR Smith
# 415  729313  NaN  2014-04-28  Sandeep Sharma
# 417  729317  NaN  2014-04-30         B Kumar
#
#                                    venue  neutral_venue  \
# 399              Sharjah Cricket Stadium              1
# 402  Dubai International Cricket Stadium              1
# 403  Dubai International Cricket Stadium              1
# 404              Sharjah Cricket Stadium              1
# ...

# %%
# getting index of rows where city is null and stadium is Sharjah Cricket Stadium
df[(df['city'].isnull()) & (df['venue']=='Sharjah Cricket Stadium')].index
# Out:
# Int64Index([399, 404, 406, 408, 413, 414], dtype='int64')

# %%
# replacing null values in city with Sharjah where venue=Sharjah Cricket Stadium
for i in [399, 404, 406, 408, 413, 414]:
    df['city'][i]='Sharjah'
# Out:
# C:\Users\CHANDANA\AppData\Local\Temp\ipykernel_24680\2518660153.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['city'][i]='Sharjah'

# %%
df[(df.city.isnull()) & (df.venue=='Dubai International Cricket Stadium')].index
# Out:
# Int64Index([402, 403, 407, 409, 410, 415, 417], dtype='int64')

# %%
# replacing null values in city with Dubai where venue='Dubai International Cricket Stadium'
for i in [402, 403, 407, 409, 410, 415, 417]:
    df['city'][i]='Dubai'
# Out:
# C:\Users\CHANDANA\AppData\Local\Temp\ipykernel_24680\1495365476.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['city'][i]='Dubai'

# %%
df.isnull().sum()
# Out:
# id                   0
# city                 0
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
df[(df.player_of_match.isnull())]
# Out:
#           id       city        date player_of_match                  venue  \
# 241   501265      Delhi  2011-05-21             NaN       Feroz Shah Kotla
# 486   829763  Bangalore  2015-04-29             NaN  M Chinnaswamy Stadium
# 511   829813  Bangalore  2015-05-17             NaN  M Chinnaswamy Stadium
# 744  1178424  Bengaluru  2019-04-30             NaN  M.Chinnaswamy Stadium
#
#      neutral_venue                        team1             team2  \
# 241              0             Delhi Daredevils     Pune Warriors
# 486              0  Royal Challengers Bangalore  Rajasthan Royals
# 511              0  Royal Challengers Bangalore  Delhi Daredevils
# 744              0  Royal Challengers Bangalore  Rajasthan Royals
#
#                      toss_winner toss_decision winner result  result_margin  \
# 241             Delhi Daredevils           bat    NaN    NaN            NaN
# 486             Rajasthan Royals         field    NaN    NaN            NaN
# ...

# %% [markdown]
# # Conclusion:
# By the above output we can see these 4 rows don't have values for player_of_match, winner, result, result_margin so it is better to drop these 4 records

# %%
df[(df.player_of_match.isnull())].index
# Out:
# Int64Index([241, 486, 511, 744], dtype='int64')

# %%
df.drop([241, 486, 511, 744],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                   0
# city                 0
# date                 0
# player_of_match      0
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               0
# result               0
# result_margin       13
# eliminator           0
# method             793
# umpire1              0
# umpire2              0
# dtype: int64

# %%
df[(df.result_margin.isnull())]
# Out:
#           id       city        date player_of_match  \
# 66    392190  Cape Town  2009-04-23       YK Pathan
# 130   419121    Chennai  2010-03-21        J Theron
# 328   598004  Hyderabad  2013-04-07       GH Vihari
# 341   598017  Bangalore  2013-04-16         V Kohli
# 416   729315  Abu Dhabi  2014-04-29     JP Faulkner
# 476   829741  Ahmedabad  2015-04-21        SE Marsh
# 610  1082625     Rajkot  2017-04-29       KH Pandya
# 705  1175365      Delhi  2019-03-30         PP Shaw
# 746  1178426     Mumbai  2019-05-02       JJ Bumrah
# 757  1216493      Dubai  2020-09-20      MP Stoinis
# 776  1216512  Abu Dhabi  2020-10-18     LH Ferguson
# 781  1216517      Dubai  2020-10-18        KL Rahul
# 811  1216547      Dubai  2020-09-28  AB de Villiers
#
#                                          venue  neutral_venue  \
# 66                                    Newlands              1
# 130            MA Chidambaram Stadium, Chepauk              0
# ...

# %% [markdown]
# As the above matches ended as 'Tie' the appropriate result margin would be '0'

# %%
df.result_margin.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# id                   0
# city                 0
# date                 0
# player_of_match      0
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               0
# result               0
# result_margin        0
# eliminator           0
# method             793
# umpire1              0
# umpire2              0
# dtype: int64

# %% [markdown]
# 'method' column has large number of null values

# %%
df[(df.method.isnull())]
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.method.unique()
# Out:
# array([nan, 'D/L'], dtype=object)

# %%
df.method.fillna('normal_method',inplace=True)

# %%
df.isnull().sum()
# Out:
# id                 0
# city               0
# date               0
# player_of_match    0
# venue              0
# neutral_venue      0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# eliminator         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %% [markdown]
# check for duplicated values

# %%
df.city.unique()
# Out:
# array(['Bangalore', 'Chandigarh', 'Delhi', 'Mumbai', 'Kolkata', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', 'Sharjah', 'Dubai', 'Rajkot', 'Kanpur', 'Bengaluru'],
#       dtype=object)

# %%
df.venue.unique()
# Out:
# array(['M Chinnaswamy Stadium',
#        'Punjab Cricket Association Stadium, Mohali', 'Feroz Shah Kotla',
#        'Wankhede Stadium', 'Eden Gardens', 'Sawai Mansingh Stadium',
#        'Rajiv Gandhi International Stadium, Uppal',
#        'MA Chidambaram Stadium, Chepauk', 'Dr DY Patil Sports Academy',
#        'Newlands', "St George's Park", 'Kingsmead', 'SuperSport Park',
#        'Buffalo Park', 'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera', 'Barabati Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
#        'Holkar Cricket Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Subrata Roy Sahara Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'JSCA International Stadium Complex', 'Sheikh Zayed Stadium',
# ...

# %%
df.venue=df.venue.replace(['M Chinnaswamy Stadium','M.Chinnaswamy Stadium'],'M.Chinnaswamy Stadium')

# %%
df.team1.unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %%
df.team1=df.team1.replace(['Rising Pune Supergiant'],'Rising Pune Supergiants')

# %%
df.team2.unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Royal Challengers Bangalore', 'Deccan Chargers',
#        'Kings XI Punjab', 'Delhi Daredevils', 'Mumbai Indians',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Delhi Capitals'], dtype=object)

# %%
df.team2=df.team2.replace(['Rising Pune Supergiant'],'Rising Pune Supergiants')

# %%
df.toss_winner=df.toss_winner.replace(['Rising Pune Supergiant'],'Rising Pune Supergiants')

# %%
df.winner=df.winner.replace(['Rising Pune Supergiant'],'Rising Pune Supergiants')

# %% [markdown]
# # EDA

# %%
ax=df.winner.value_counts().plot(kind='bar')
for i in ax.containers:
    ax.bar_label(i,color='orange');

# %% [markdown]
# MUMBAI INDIANS WON THE HIGHEST NO. OF MATCHES FOLLOWED BY CSK

# %%
pd.crosstab(df.city,df.winner).plot.bar(stacked=True);

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M.Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
ax=df.player_of_match.value_counts().nlargest(10).plot(kind='bar')
for i in ax.containers:
    ax.bar_label(i,size=10,color='r')

# %% [markdown]
# Hghest Number of MOM Awards were bagged by ABD

# %%
df.toss_decision.value_counts().plot(kind='pie',autopct='%.2f%%');

# %% [markdown]
# Most Of The Times The team Winning The Toss Opt to Field in IPL(Teams Like To Chase More)

# %%
ax=df.toss_winner.value_counts().plot.bar()
for i in ax.containers:
    ax.bar_label(i,size=10,color='g');

# %% [markdown]
# MI won the toss most number of times

# %%
ax=df[df.toss_winner==df.winner].winner.value_counts().plot.bar()
for i in ax.containers:
    ax.bar_label(i,size=10,color='r');

# %% [markdown]
# CSK AND MI WON MOST MATCHES WHEN THEY WON THE TOSS

# %%
ax=df[df.toss_winner!=df.winner].winner.value_counts().plot.bar()
for i in ax.containers:
    ax.bar_label(i,size=10,color='g');

# %% [markdown]
# MI LOST MOST MATCHES WHEN THEY WON THE TOSS FOLLOWED BY KINGS XI PUNJAB

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M.Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
tie=df[df.result=='tie']

# %%
ax=tie.winner.value_counts().plot.bar()
for i in ax.containers:
    ax.bar_label(i,size=10,color='r');

# %% [markdown]
# WHEN MATCH_RESULT WAS TIE KINGS XI PUNJAB WON MOST MATCHES IN SUPER OVER

# %%
result_wkts=df[df.result=='wickets']
result_runs=df[df.result=='runs']

# %%
ax=result_wkts.winner.value_counts().plot.bar()
for i in ax.containers:
    ax.bar_label(i,color='r')

# %% [markdown]
# MOST MATCHES WON BY KKR WHILE CHASING A TARGET

# %%
ax=result_runs.winner.value_counts().plot.bar()
for i in ax.containers:
    ax.bar_label(i,color='r')

# %% [markdown]
# MOST MATCHES WON BY MI WHILE DEFENDING A TARGET

# %%
# most matches won in home_ground

# %%
homegroundwins=df[(df.neutral_venue==0)&(df.team1==df.winner)]

# %%
homegroundwins.winner.value_counts()
# Out:
# Mumbai Indians                 61
# Chennai Super Kings            56
# Kolkata Knight Riders          54
# Rajasthan Royals               43
# Royal Challengers Bangalore    43
# Kings XI Punjab                41
# Sunrisers Hyderabad            36
# Delhi Daredevils               31
# Delhi Capitals                 12
# Deccan Chargers                 8
# Rising Pune Supergiants         7
# Pune Warriors                   6
# Gujarat Lions                   5
# Kochi Tuskers Kerala            3
# Name: winner, dtype: int64

# %% [markdown]
# MI,CSK,KKR Are Dominant In Their Homegrounds

# %%
awaywins=df[(df.neutral_venue==1)&(df.team1==df.winner)]

# %%
ax=awaywins.winner.value_counts().plot.bar()
for i in ax.containers:
    ax.bar_label(i,color='r')

# %% [markdown]
# RCB and CSK are DOMINANT when IPL is conducted abroad , MI performed the worst

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M.Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...
